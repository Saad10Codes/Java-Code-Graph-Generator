# %%
import sys
import import_ipynb
import networkx as nx
from antlr4 import *
from antlr4.InputStream import InputStream
import inspect
import matplotlib.pyplot as plt
import pickle
import os

from JavaLexer import JavaLexer
from JavaParser import JavaParser
from JavaParserListener import JavaParserListener
from JavaParserVisitor import JavaParserVisitor

from Map2Graphs.ShowGraphs import show_graph,show_graph_pyvis

# %%
class CustomListener(JavaParserListener):
    def __init__(self):
        self.stack=[]
        self.identifier_table=[]
        self.graph=nx.MultiDiGraph()
        self.graph.graph['Graphid'] = 'MyGraph' 
        self.keyword_dict=["for","if","else","while","switch","try","catch","finally"]
        self.keyword_dict = {keyword: 0 for keyword in self.keyword_dict}
        self.entered_class_flag=False
        print(self.keyword_dict)

    def isInsideContext(self, ctx, ancestor):
        # Traverse upwards in the parse tree to check if a for statement is an ancestor
        parent = ctx.parentCtx
        while parent is not None:
            if isinstance(parent, JavaParser.ForInitContext):
                return True
            parent = parent.parentCtx
        return False


    def enterCompilationUnit(self, ctx:JavaParser.CompilationUnitContext):
        self.stack.append('compilation_unit')
        
    def enterClassDeclaration(self, ctx:JavaParser.ClassDeclarationContext):
        self.stack.append(ctx.children[1].getText())
        self.graph.add_node(ctx.children[1].getText())
        self.entered_class_flag=True
        
    def enterMethodDeclaration(self, ctx:JavaParser.MethodDeclarationContext):
        # print("Enter method")
        for child in ctx.children:
            if isinstance(child, JavaParser.IdentifierContext):
                self.stack.append(child.getText())
                self.graph.add_node(child.getText(),label=child.getText())
                self.graph.add_edge(self.stack[-2],child.getText(),label='contains')
                print("APPENDING METHOD AND CLASS",self.stack[-1],child.getText())
                print(self.stack)

    # Exit a parse tree produced by JavaParser#methodDeclaration.
    # def exitMethodDeclaration(self, ctx:JavaParser.MethodDeclarationContext):
        # print("exit method declaration")


    # Enter a parse tree produced by JavaParser#methodBody.
    # def enterMethodBody(self, ctx:JavaParser.MethodBodyContext):
        # print("enter method body")
    
    # Exit a parse tree produced by JavaParser#methodBody.
    # def exitMethodBody(self, ctx:JavaParser.MethodBodyContext):
        # print("exit method body")

    # ## Statement is a child of blockStatement
    
     # Enter a parse tree produced by JavaParser#blockStatement.
    def enterStatement(self, ctx:JavaParser.BlockStatementContext):
        # print("Entering statement")
        for child in ctx.children:
            if child.getText() in ["for","if","else","while","switch","try","catch","finally"]:
                self.keyword_dict[child.getText()]+=1
                block_node=child.getText()+'_'+str(self.keyword_dict[child.getText()])
                self.graph.add_edge(self.stack[-1],block_node,label="contains")
                self.stack.append(block_node)
                self.graph.nodes[block_node]['label'] = block_node
                print(self.stack)
 
    # Exit a parse tree produced by JavaParser#blockStatement.
    # def exitStatement(self, ctx:JavaParser.BlockStatementContext):
        # print("Exiting statement")

    def enterBlock(self, ctx:JavaParser.BlockContext):
        print(self.stack[-1],"block entered")  

    def enterForControl(self, ctx:JavaParser.ForControlContext):
        if isinstance(ctx.children[0],JavaParser.EnhancedForControlContext):
            self.graph.add_edge(self.stack[-1],'enhanced_for',label='condition')
        else:
            if len(ctx.children)>=3:
                self.graph.add_edge(self.stack[-1],ctx.children[2].getText(),label='condition')
                self.graph.nodes[ctx.children[2].getText()]['label'] = ctx.children[2].getText()

    def enterExpression(self, ctx:JavaParser.ExpressionContext):
        new_node=''
        if hasattr(ctx,'bop') and ctx.bop!=None:
            # print("The bop of this expression is ",ctx.bop.text, ctx.getText())
            if ctx.bop.text=='=':
                new_node='assign::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='+=':
                new_node='increment::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='-=':
                new_node='decrement::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='*=':
                new_node='multiply::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='/=':
                new_node='divide::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='%=':
                new_node='mod::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='==':
                new_node='compareEqualTo::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='<=':
                new_node='compareLessThanOrEqual::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='<':
                new_node='compareLessThan::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='>=':
                new_node='compareGreaterThanOrEqual::'+ctx.children[0].getText()+':'+ctx.children[2].getText()
            if ctx.bop.text=='>':
                new_node='compareGreaterThanOrEqual::'+ctx.children[0].getText()+':'+ctx.children[2].getText()

            if new_node!='':
                self.graph.add_edge(self.stack[-1],new_node,label='contains')
                self.graph.nodes[new_node]['label']=new_node
                
        if hasattr(ctx,'postfix') and ctx.postfix!=None:
            if ctx.postfix.text=='++':
                new_node='increment::'+ctx.children[0].getText()+':1'
            if ctx.postfix.text=='--':
                new_node='decrement::'+ctx.children[0].getText()+':1'
                
            if new_node!='':   
                self.graph.add_edge(self.stack[-1],new_node,label='contains')
                self.graph.nodes[new_node]['label']=new_node
                
        if hasattr(ctx,'prefix') and ctx.prefix!=None:
            if ctx.prefix.text=='++':
                new_node='increment::'+ctx.children[0].getText()+':1'
            if ctx.prefix.text=='--':
                new_node='decrement::'+ctx.children[0].getText()+':1'
            if new_node!='':
                self.graph.add_edge(self.stack[-1],new_node,label='contains')
                self.graph.nodes[new_node]['label']=new_node
        # if new_node!='':
        #     print('adding node new_node',new_node)
            
    def enterParExpression(self, ctx:JavaParser.ParExpressionContext):
        if ctx.parentCtx.children[0].getText()in ['if','while','switch','catch']:
            if(self.stack[-1]=='else'):
                self.graph.add_edge(self.stack[-2],ctx.getText().lstrip('(').rstrip(')'),label='condition')
                self.graph.nodes[ctx.getText().lstrip('(').rstrip(')')]['label'] = ctx.getText().lstrip('(').rstrip(')')
                # print('adding node',ctx.getText().lstrip('(').rstrip(')'))
            else:
                self.graph.add_edge(self.stack[-1],ctx.getText().lstrip('(').rstrip(')'),label='condition')
                self.graph.nodes[ctx.getText().lstrip('(').rstrip(')')]['label'] = ctx.getText().lstrip('(').rstrip(')')
                # print('adding node',ctx.getText().lstrip('(').rstrip(')'))
    
    # Exit a parse tree produced by JavaParser#block.
    def exitBlock(self, ctx:JavaParser.BlockContext):
        if len(self.stack)>2:
            self.stack.pop()

    def enterIdentifier(self, ctx:JavaParser.IdentifierContext):
        # if self.isInsideContext(ctx,JavaParser.ForInitContext):
        #     self.graph.add_edge(self.stack[-1],ctx.getText(),label='contains')
            
        flag=False
        j=0
        # print(ctx.parentCtx.getText())
        if not isinstance(ctx.parentCtx,JavaParser.ClassDeclarationContext) and not isinstance(ctx.parentCtx,JavaParser.MethodDeclarationContext):
            for i in self.identifier_table:
                if ctx.getText() == i:
                    flag=True
                    break
                j+=1
                    
            if flag==False:
                self.identifier_table.append(ctx.getText())
                print(self.stack)
                if not self.graph.has_edge(self.stack[-1],ctx.getText()):
                    self.graph.add_edge(self.stack[-1],ctx.getText(),label='contains')
                    self.graph.nodes[ctx.getText()]['label'] = ctx.getText()
            else:
                if not self.graph.has_edge(self.stack[-1],self.identifier_table[j]):
                    self.graph.add_edge(self.stack[-1],self.identifier_table[j],label='contains')
                    self.graph.nodes[self.identifier_table[j]]['label'] = self.identifier_table[j]
                    

    def enterLocalVariableDeclaration(self, ctx:JavaParser.LocalVariableDeclarationContext):
        # get the variable type
        var_type=ctx.children[0].getText()
        
        # list containing the list of variable declarator instances
        declarator_list=[]

        # list containing the list of all variables with identifier and value if present
        var_list=[]
        
        # append the child to declarator_list if it is a varibale declarator instance
        for child in ctx.children[1].children:
            if isinstance(child,JavaParser.VariableDeclaratorContext):
                declarator_list.append(child)
                
        for dec in declarator_list:
            # append the initial value of the variable if present else ignore.
            # attach the string with the var type 
            if isinstance(dec.children[-1],JavaParser.VariableInitializerContext):
                var_list.append(dec.children[0].getText())
                # +'_'+var_type+':'+dec.children[-1].getText()
            else:
                var_list.append(dec.children[0].getText())
                # var_type+'_'+
        for var in var_list:
            self.graph.add_edge(self.stack[-1],var,label='contains')
            self.graph.nodes[var]['label'] = var
            self.identifier_table.append(var)
            # print('adding node',var)
            
    def enterFormalParameter(self, ctx:JavaParser.FormalParameterContext):
        var_type=ctx.children[0].getText()
        var_name=ctx.children[-1].getText()
        self.graph.add_edge(self.stack[-1],var_name,label='parameter')
        # +'_'+var_type 
        self.identifier_table.append(var_name)
        self.graph.nodes[var_name]['label'] = var_name
        # print('adding node',var_name)


    def enterMethodCall(self, ctx:JavaParser.MethodCallContext):
        called_method=ctx.children[0].getText()
        if '.' in ctx.parentCtx.getText():
            called_method+='_from:'+ctx.parentCtx.children[0].getText()
        self.graph.add_edge(self.stack[-1],called_method,label='contains')
        self.graph.nodes[called_method]['label']=called_method
        print('adding node',called_method)
        # print("METHOD CALL!!!!!!",ctx.children[1].getText(),ctx.children[1].children[1].getText())
        arguments=ctx.children[1].children[1].getText().split(',')
        for arg in arguments:
            self.graph.add_edge(called_method,arg,label='parameters')
            self.graph.nodes[arg]['label']=arg 
            print('adding node',arg)

# %%
class JavaParseGraph(JavaParserVisitor):
    
    def __init__(self,directories):
        self.directories=directories
        self.locations=self.list_java_files(self.directories)
        self.graphs=[]

    def list_java_files(self,directories):
        for directory in directories:
            return [os.path.join(directory, f) for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f)) and f.endswith('.java')]

    def parse_tree_generator(self):
        for location in self.locations:
            try:
                print('USING', location)
                input_code = FileStream(location, encoding='utf-8')  # Specify encoding to handle non-ASCII characters
                lexer = JavaLexer(input_code)
                stream = CommonTokenStream(lexer)
                parser = JavaParser(stream)
                tree = parser.compilationUnit()
                print(tree.toStringTree(recog=parser))
                
                walker = ParseTreeWalker()
                customWalker = CustomListener()   
                walker.walk(customWalker, tree)
                
                self.graphs.append(customWalker.graph)
                print(customWalker.stack, list(customWalker.graph.edges(data=True)))
                print(customWalker.identifier_table)
                # nx.draw(customWalker.graph,with_labels=True)
                # edge_labels = nx.get_edge_attributes(customWalker.graph, 'label')
                # nx.draw_networkx_edge_labels(customWalker.graph,  edge_labels=edge_labels)
                # plt.show()
                # show_graph(customWalker.graph)
                # show_graph_pyvis(customWalker.graph,output_filename='graph.html')
                
            except UnicodeDecodeError as e:
                print(f"UnicodeDecodeError: {e}. Skipping file {location}.")
            except Exception as e:
                print(f"An error occurred: {e}. Skipping file {location}.")
            
        print('All graphs have been generated')
        return self.graphs
javaParse=JavaParseGraph(["TwoProgramsForComparison"])

with open('java_graphs_two_comparison.pkl', 'wb') as f:
    pickle.dump(javaParse.parse_tree_generator(), f)
# Out:
# USING TwoProgramsForComparison\binary_search_using_for.java
# (compilationUnit (typeDeclaration (classDeclaration class (identifier BinSearch) (classBody { (classBodyDeclaration (modifier (classOrInterfaceModifier public)) (modifier (classOrInterfaceModifier static)) (memberDeclaration (methodDeclaration (typeTypeOrVoid (typeType (primitiveType boolean))) (identifier binarySearch) (formalParameters ( (formalParameterList (formalParameter (typeType (primitiveType int) [ ]) (variableDeclaratorId (identifier array))) , (formalParameter (typeType (primitiveType int)) (variableDeclaratorId (identifier value)))) )) (methodBody (block { (blockStatement (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier end)) = (variableInitializer (expression (expression (expression (primary (identifier array))) . (identifier length)) - (expression (primary (literal (integerLiteral 1))))))))) ;) (blockStatement (statement for ( (forControl (forInit (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier start)) = (variableInitializer (expression (primary (literal (integerLiteral 0))))))))) ; (expression (expression (primary (identifier start))) < (expression (primary (identifier end)))) ; (expressionList (expression (primary (identifier start))))) ) (statement (block { (blockStatement (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier middle)) = (variableInitializer (expression (expression (primary ( (expression (expression (primary (identifier end))) + (expression (primary (identifier start)))) ))) / (expression (primary (literal (integerLiteral 2))))))))) ;) (blockStatement (statement if (parExpression ( (expression (expression (expression (primary (identifier array))) [ (expression (primary (identifier middle))) ]) == (expression (primary (identifier value)))) )) (statement (block { (blockStatement (statement return (expression (primary (literal true))) ;)) })) else (statement if (parExpression ( (expression (expression (expression (primary (identifier array))) [ (expression (primary (identifier middle))) ]) > (expression (primary (identifier value)))) )) (statement (block { (blockStatement (statement (expression (expression (primary (identifier end))) = (expression (expression (primary (identifier middle))) - (expression (primary (literal (integerLiteral 1)))))) ;)) })) else (statement (block { (blockStatement (statement (expression (expression (primary (identifier start))) = (expression (expression (primary (identifier middle))) + (expression (primary (literal (integerLiteral 1)))))) ;)) }))))) })))) (blockStatement (statement return (expression (primary (literal false))) ;)) }))))) }))))
# {'for': 0, 'if': 0, 'else': 0, 'while': 0, 'switch': 0, 'try': 0, 'catch': 0, 'finally': 0}
# APPENDING METHOD AND CLASS binarySearch binarySearch
# ['compilation_unit', 'BinSearch', 'binarySearch']
# binarySearch block entered
# ['compilation_unit', 'BinSearch', 'binarySearch']
# ['compilation_unit', 'BinSearch', 'binarySearch', 'for_1']
# for_1 block entered
# ['compilation_unit', 'BinSearch', 'binarySearch', 'for_1', 'if_1']
# ['compilation_unit', 'BinSearch', 'binarySearch', 'for_1', 'if_1', 'else_1']
# else_1 block entered
# ['compilation_unit', 'BinSearch', 'binarySearch', 'for_1', 'if_1', 'if_2']
# ['compilation_unit', 'BinSearch', 'binarySearch', 'for_1', 'if_1', 'if_2', 'else_2']
# else_2 block entered
# if_2 block entered
# ['compilation_unit', 'BinSearch', 'binarySearch'] [('binarySearch', 'binarySearch', {'label': 'contains'}), ('binarySearch', 'array', {'label': 'parameter'}), ('binarySearch', 'value', {'label': 'parameter'}), ('binarySearch', 'end', {'label': 'contains'}), ('binarySearch', 'length', {'label': 'contains'}), ('binarySearch', 'for_1', {'label': 'contains'}), ('for_1', 'start<end', {'label': 'condition'}), ('for_1', 'start', {'label': 'contains'}), ('for_1', 'compareLessThan::start:end', {'label': 'contains'}), ('for_1', 'end', {'label': 'contains'}), ('for_1', 'middle', {'label': 'contains'}), ('for_1', 'if_1', {'label': 'contains'}), ('if_1', 'else_1', {'label': 'contains'}), ('if_1', 'if_2', {'label': 'contains'}), ('else_1', 'array[middle]==value', {'label': 'condition'}), ('else_1', 'compareEqualTo::array[middle]:value', {'label': 'contains'}), ('else_1', 'array', {'label': 'contains'}), ('else_1', 'middle', {'label': 'contains'}), ('else_1', 'value', {'label': 'contains'}), ('if_2', 'else_2', {'label': 'contains'}), ('if_2', 'assign::start:middle+1', {'label': 'contains'}), ('if_2', 'start', {'label': 'contains'}), ('if_2', 'middle', {'label': 'contains'}), ('else_2', 'array[middle]>value', {'label': 'condition'}), ('else_2', 'compareGreaterThanOrEqual::array[middle]:value', {'label': 'contains'}), ('else_2', 'array', {'label': 'contains'}), ('else_2', 'middle', {'label': 'contains'}), ('else_2', 'value', {'label': 'contains'}), ('else_2', 'assign::end:middle-1', {'label': 'contains'}), ('else_2', 'end', {'label': 'contains'})]
# ['array', 'value', 'end', 'length', 'start', 'middle']
# USING TwoProgramsForComparison\binary_search_using_while.java
# (compilationUnit (typeDeclaration (classDeclaration class (identifier BinSearchWhile) (classBody { (classBodyDeclaration (modifier (classOrInterfaceModifier public)) (modifier (classOrInterfaceModifier static)) (memberDeclaration (methodDeclaration (typeTypeOrVoid (typeType (primitiveType boolean))) (identifier binarySearch) (formalParameters ( (formalParameterList (formalParameter (typeType (primitiveType int) [ ]) (variableDeclaratorId (identifier array))) , (formalParameter (typeType (primitiveType int)) (variableDeclaratorId (identifier value)))) )) (methodBody (block { (blockStatement (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier end)) = (variableInitializer (expression (expression (expression (primary (identifier array))) . (identifier length)) - (expression (primary (literal (integerLiteral 1))))))))) ;) (blockStatement (statement while (parExpression ( (expression (expression (primary (identifier start))) < (expression (primary (identifier end)))) )) (statement (block { (blockStatement (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier middle)) = (variableInitializer (expression (expression (primary ( (expression (expression (primary (identifier end))) + (expression (primary (identifier start)))) ))) / (expression (primary (literal (integerLiteral 2))))))))) ;) (blockStatement (statement if (parExpression ( (expression (expression (expression (primary (identifier array))) [ (expression (primary (identifier middle))) ]) == (expression (primary (identifier value)))) )) (statement (block { (blockStatement (statement return (expression (primary (literal true))) ;)) })) else (statement if (parExpression ( (expression (expression (expression (primary (identifier array))) [ (expression (primary (identifier middle))) ]) > (expression (primary (identifier value)))) )) (statement (block { (blockStatement (statement (expression (expression (primary (identifier end))) = (expression (expression (primary (identifier middle))) - (expression (primary (literal (integerLiteral 1)))))) ;)) })) else (statement (block { (blockStatement (statement (expression (expression (primary (identifier start))) = (expression (expression (primary (identifier middle))) + (expression (primary (literal (integerLiteral 1)))))) ;)) }))))) })))) (blockStatement (statement return (expression (primary (literal false))) ;)) }))))) }))))
# {'for': 0, 'if': 0, 'else': 0, 'while': 0, 'switch': 0, 'try': 0, 'catch': 0, 'finally': 0}
# APPENDING METHOD AND CLASS binarySearch binarySearch
# ['compilation_unit', 'BinSearchWhile', 'binarySearch']
# binarySearch block entered
# ['compilation_unit', 'BinSearchWhile', 'binarySearch']
# ['compilation_unit', 'BinSearchWhile', 'binarySearch', 'while_1']
# ['compilation_unit', 'BinSearchWhile', 'binarySearch', 'while_1']
# while_1 block entered
# ['compilation_unit', 'BinSearchWhile', 'binarySearch', 'while_1', 'if_1']
# ['compilation_unit', 'BinSearchWhile', 'binarySearch', 'while_1', 'if_1', 'else_1']
# else_1 block entered
# ['compilation_unit', 'BinSearchWhile', 'binarySearch', 'while_1', 'if_1', 'if_2']
# ['compilation_unit', 'BinSearchWhile', 'binarySearch', 'while_1', 'if_1', 'if_2', 'else_2']
# else_2 block entered
# if_2 block entered
# ['compilation_unit', 'BinSearchWhile', 'binarySearch'] [('binarySearch', 'binarySearch', {'label': 'contains'}), ('binarySearch', 'array', {'label': 'parameter'}), ('binarySearch', 'value', {'label': 'parameter'}), ('binarySearch', 'end', {'label': 'contains'}), ('binarySearch', 'length', {'label': 'contains'}), ('binarySearch', 'while_1', {'label': 'contains'}), ('while_1', 'start<end', {'label': 'condition'}), ('while_1', 'compareLessThan::start:end', {'label': 'contains'}), ('while_1', 'start', {'label': 'contains'}), ('while_1', 'end', {'label': 'contains'}), ('while_1', 'middle', {'label': 'contains'}), ('while_1', 'if_1', {'label': 'contains'}), ('if_1', 'else_1', {'label': 'contains'}), ('if_1', 'if_2', {'label': 'contains'}), ('else_1', 'array[middle]==value', {'label': 'condition'}), ('else_1', 'compareEqualTo::array[middle]:value', {'label': 'contains'}), ('else_1', 'array', {'label': 'contains'}), ('else_1', 'middle', {'label': 'contains'}), ('else_1', 'value', {'label': 'contains'}), ('if_2', 'else_2', {'label': 'contains'}), ('if_2', 'assign::start:middle+1', {'label': 'contains'}), ('if_2', 'start', {'label': 'contains'}), ('if_2', 'middle', {'label': 'contains'}), ('else_2', 'array[middle]>value', {'label': 'condition'}), ('else_2', 'compareGreaterThanOrEqual::array[middle]:value', {'label': 'contains'}), ('else_2', 'array', {'label': 'contains'}), ('else_2', 'middle', {'label': 'contains'}), ('else_2', 'value', {'label': 'contains'}), ('else_2', 'assign::end:middle-1', {'label': 'contains'}), ('else_2', 'end', {'label': 'contains'})]
# ['array', 'value', 'end', 'length', 'start', 'middle']
# USING TwoProgramsForComparison\factorial_program_in_java.java
# (compilationUnit (typeDeclaration (classDeclaration class (identifier FactorialExample) (classBody { (classBodyDeclaration (modifier (classOrInterfaceModifier public)) (modifier (classOrInterfaceModifier static)) (memberDeclaration (methodDeclaration (typeTypeOrVoid void) (identifier main) (formalParameters ( (formalParameterList (formalParameter (typeType (classOrInterfaceType (typeIdentifier String))) (variableDeclaratorId (identifier args) [ ]))) )) (methodBody (block { (blockStatement (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier i))) , (variableDeclarator (variableDeclaratorId (identifier fact)) = (variableInitializer (expression (primary (literal (integerLiteral 1)))))))) ;) (blockStatement (localVariableDeclaration (typeType (primitiveType int)) (variableDeclarators (variableDeclarator (variableDeclaratorId (identifier number)) = (variableInitializer (expression (primary (literal (integerLiteral 5)))))))) ;) (blockStatement (statement for ( (forControl (forInit (expressionList (expression (expression (primary (identifier i))) = (expression (primary (literal (integerLiteral 1))))))) ; (expression (expression (primary (identifier i))) <= (expression (primary (identifier number)))) ; (expressionList (expression (expression (primary (identifier i))) ++))) ) (statement (block { (blockStatement (statement (expression (expression (primary (identifier fact))) = (expression (expression (primary (identifier fact))) * (expression (primary (identifier i))))) ;)) })))) (blockStatement (statement (expression (expression (expression (primary (identifier System))) . (identifier out)) . (methodCall (identifier println) (arguments ( (expressionList (expression (expression (expression (expression (primary (literal "Factorial of "))) + (expression (primary (identifier number)))) + (expression (primary (literal " is: ")))) + (expression (primary (identifier fact))))) )))) ;)) }))))) }))))
# {'for': 0, 'if': 0, 'else': 0, 'while': 0, 'switch': 0, 'try': 0, 'catch': 0, 'finally': 0}
# APPENDING METHOD AND CLASS main main
# ['compilation_unit', 'FactorialExample', 'main']
# ['compilation_unit', 'FactorialExample', 'main']
# main block entered
# ['compilation_unit', 'FactorialExample', 'main', 'for_1']
# for_1 block entered
# ['compilation_unit', 'FactorialExample', 'main']
# ['compilation_unit', 'FactorialExample', 'main']
# adding node println_from:System.out
# adding node "Factorial of "+number+" is: "+fact
# ['compilation_unit', 'FactorialExample', 'main']
# ['compilation_unit', 'FactorialExample'] [('main', 'main', {'label': 'contains'}), ('main', 'args[]', {'label': 'parameter'}), ('main', 'args', {'label': 'contains'}), ('main', 'i', {'label': 'contains'}), ('main', 'fact', {'label': 'contains'}), ('main', 'number', {'label': 'contains'}), ('main', 'for_1', {'label': 'contains'}), ('main', 'System', {'label': 'contains'}), ('main', 'out', {'label': 'contains'}), ('main', 'println_from:System.out', {'label': 'contains'}), ('main', 'println', {'label': 'contains'}), ('for_1', 'i<=number', {'label': 'condition'}), ('for_1', 'assign::i:1', {'label': 'contains'}), ('for_1', 'i', {'label': 'contains'}), ('for_1', 'compareLessThanOrEqual::i:number', {'label': 'contains'}), ('for_1', 'number', {'label': 'contains'}), ('for_1', 'increment::i:1', {'label': 'contains'}), ('for_1', 'assign::fact:fact*i', {'label': 'contains'}), ('for_1', 'fact', {'label': 'contains'}), ('println_from:System.out', '"Factorial of "+number+" is: "+fact', {'label': 'parameters'})]
# ['args[]', 'args', 'i', 'fact', 'number', 'System', 'out', 'println']
# All graphs have been generated

# %%
import pickle
import networkx as nx

# Load the list of graphs from the file
with open('java_graphs1.pkl', 'rb') as f:
    graphs1 = pickle.load(f)

with open('java_graphs.pkl', 'rb') as f:
    graphs2 = pickle.load(f)

graphs1+=graphs2

with open('java_graphs_total.pkl', 'wb') as f:
    pickle.dump(graphs1, f)
# Example usage: print information about each graph
print(len(graphs1))
# for i, graph in enumerate(graphs):
#     print(f"Graph {i}:")
#     print(f"Number of nodes: {graph.number_of_nodes()}")
#     print(f"Number of edges: {graph.number_of_edges()}")
#     print(f"Nodes: {list(graph.nodes(data=True))}")
#     print(f"Edges: {list(graph.edges(data=True))}")
# Out:
# 1492

# %%
with open('java_graphs_total.pkl', 'rb') as f:
    graphs = pickle.load(f)

print(len(graphs))
# Out:
# 1492

# %%
import os

def list_java_files(directories):
    for directory in directories:
        return [os.path.join(directory, f) for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f)) and f.endswith('.java')]

# Specify the directory
directory = ['JavaCorpus','JavaPrograms2']

# Get the list of Java filenames with directory path
java_files = list_java_files(directory)
print(java_files)
# Out:
# ['JavaCorpus\\About.java', 'JavaCorpus\\AboutDialog.java', 'JavaCorpus\\AbstractAnnotationSourceManager.java', 'JavaCorpus\\AbstractArrayAdapter.java', 'JavaCorpus\\AbstractChart.java', 'JavaCorpus\\AbstractCluster.java', 'JavaCorpus\\AbstractComm.java', 'JavaCorpus\\AbstractDao.java', 'JavaCorpus\\AbstractImmutableBag.java', 'JavaCorpus\\AbstractImmutableList.java', 'JavaCorpus\\AbstractListAdapter.java', 'JavaCorpus\\AbstractMemoryEfficientMutableList.java', 'JavaCorpus\\AbstractMutableList.java', 'JavaCorpus\\AbstractPartitionMutableSet.java', 'JavaCorpus\\AbstractTcpClient.java', 'JavaCorpus\\AbstractTcpServer.java', 'JavaCorpus\\AbstractTokenizer.java', 'JavaCorpus\\AbstractTool.java', 'JavaCorpus\\Account.java', 'JavaCorpus\\AccountMapper.java', 'JavaCorpus\\AccountSummary.java', 'JavaCorpus\\Act.java', 'JavaCorpus\\Action.java', 'JavaCorpus\\ActionFixture.java', 'JavaCorpus\\ActionShow.java', 'JavaCorpus\\ActionShowAdapter.java', 'JavaCorpus\\ActivitiesManager.java', 'JavaCorpus\\Activity.java', 'JavaCorpus\\ActPaint.java', 'JavaCorpus\\Actuator.java', 'JavaCorpus\\ActuatorAdapter.java', 'JavaCorpus\\ActuatorFunction.java', 'JavaCorpus\\AddAction.java', 'JavaCorpus\\addBottleGUI.java', 'JavaCorpus\\AddItemizedOverlay.java', 'JavaCorpus\\AddNewView.java', 'JavaCorpus\\Address.java', 'JavaCorpus\\AddressBook.java', 'JavaCorpus\\Addresses.java', 'JavaCorpus\\AddressOverlay.java', 'JavaCorpus\\AddTrigger.java', 'JavaCorpus\\AddWindow.java', 'JavaCorpus\\AdnanNLP.java', 'JavaCorpus\\Ads.java', 'JavaCorpus\\AdvancedSearch.java', 'JavaCorpus\\Alarm.java', 'JavaCorpus\\AlarmClock.java', 'JavaCorpus\\AlarmDBAdapter.java', 'JavaCorpus\\AlarmEdit.java', 'JavaCorpus\\AlarmReceiver.java', 'JavaCorpus\\AlarmService.java', 'JavaCorpus\\Alramd.java', 'JavaCorpus\\AlramReceiver.java', 'JavaCorpus\\AndroidAudioDevice.java', 'JavaCorpus\\AngryCommentResource.java', 'JavaCorpus\\AngryPostLinkable.java', 'JavaCorpus\\AngryPostResource.java', 'JavaCorpus\\AnimationPanel.java', 'JavaCorpus\\AnnotationSource.java', 'JavaCorpus\\AnnotationSourceConverter.java', 'JavaCorpus\\AnnotationSourceDAO.java', 'JavaCorpus\\AnnotationSourceInputValidator.java', 'JavaCorpus\\AnnotationSourceProperties.java', 'JavaCorpus\\AntiCaps.java', 'JavaCorpus\\AntiCapsEvent.java', 'JavaCorpus\\ApiGateway.java', 'JavaCorpus\\ApiRequest.java', 'JavaCorpus\\ApiResponse.java', 'JavaCorpus\\ApiResponseCallbacks.java', 'JavaCorpus\\App.java', 'JavaCorpus\\AppData.java', 'JavaCorpus\\Application.java', 'JavaCorpus\\ApplicationUtil.java', 'JavaCorpus\\ApplicationWithServices.java', 'JavaCorpus\\ArchiveController.java', 'JavaCorpus\\ArchiveSelectionActivity.java', 'JavaCorpus\\Arm.java', 'JavaCorpus\\ArmController.java', 'JavaCorpus\\ArrayAdapter.java', 'JavaCorpus\\ArrayExpressConnection.java', 'JavaCorpus\\ArrayIntList.java', 'JavaCorpus\\ArrayIntStack.java', 'JavaCorpus\\ArrayListAdapter.java', 'JavaCorpus\\Artist.java', 'JavaCorpus\\ArtistScherm.java', 'JavaCorpus\\AsyncHttpClient.java', 'JavaCorpus\\AsyncHttpRequest.java', 'JavaCorpus\\AsyncHttpResponseHandler.java', 'JavaCorpus\\AtlasBioEntityDataWriter.java', 'JavaCorpus\\Attachment.java', 'JavaCorpus\\AttachmentDao.java', 'JavaCorpus\\AttachmentDaoImpl.java', 'JavaCorpus\\AttachmentService.java', 'JavaCorpus\\AttachmentServiceImpl.java', 'JavaCorpus\\Attendee.java', 'JavaCorpus\\AudioFocusHelper.java', 'JavaCorpus\\AudioFormatChooser.java', 'JavaCorpus\\Auth.java', 'JavaCorpus\\Autonomous.java', 'JavaCorpus\\AutoUpdateThread.java', 'JavaCorpus\\BackupImpl.java', 'JavaCorpus\\BackupManager.java', 'JavaCorpus\\Ball.java', 'JavaCorpus\\BallPanel.java', 'JavaCorpus\\BanConfig.java', 'JavaCorpus\\Band.java', 'JavaCorpus\\BarChart.java', 'JavaCorpus\\BarPrinter.java', 'JavaCorpus\\BaseSelectionActivity.java', 'JavaCorpus\\BaseSelectionController.java', 'JavaCorpus\\BaseUriOps.java', 'JavaCorpus\\Basic.java', 'JavaCorpus\\BasicGenomicAnnotation.java', 'JavaCorpus\\BasicTwoSubjectAnnotation.java', 'JavaCorpus\\BazPrinter.java ...

# %%
# for location in self.locations:
#             print('USING',location)
#             input_code=FileStream(location)
#             #input_stream=InputStream(input_code)
#             lexer=JavaLexer(input_code)
#             stream=CommonTokenStream(lexer)
#             parser=JavaParser(stream)
#             tree=parser.compilationUnit()
#             print(tree.toStringTree(recog=parser))
#             # visitor=CustomVisitor(self.location)
#             # visitor.visit(tree)
#             walker=ParseTreeWalker()
#             customWalker=CustomListener()   
#             walker.walk(customWalker,tree)
#             self.graphs.append(customWalker.graph)
#             print(customWalker.stack, list(customWalker.graph.edges(data=True)))
#             print(customWalker.identifier_table)
#             # nx.draw(customWalker.graph,with_labels=True)
#             # edge_labels = nx.get_edge_attributes(customWalker.graph, 'label')
#             # nx.draw_networkx_edge_labels(customWalker.graph,  edge_labels=edge_labels)
#             # plt.show()
#             # show_graph(customWalker.graph)
#             # show_graph_pyvis(customWalker.graph,output_filename='graph.html')
